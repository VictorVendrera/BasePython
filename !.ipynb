# %%
import pandas as pd

# %%
date = pd.read_excel("PesquisaPSE.xlsx")

# %%
date.head()
# Out:
#                 Timestamp                         1. Qual o seu curso?  \
# 0 2020-09-12 09:06:09.289  Análise e Desenvolvimento de Sistemas (ADS)
# 1 2020-09-12 08:44:35.583  Análise e Desenvolvimento de Sistemas (ADS)
# 2 2020-09-09 15:07:43.017  Análise e Desenvolvimento de Sistemas (ADS)
# 3 2020-09-09 15:27:31.996  Análise e Desenvolvimento de Sistemas (ADS)
# 4 2020-09-09 15:43:40.981  Análise e Desenvolvimento de Sistemas (ADS)
#
#   2. Em qual período?  \
# 0             Noturno
# 1             Noturno
# 2            Matutino
# 3             Noturno
# 4             Noturno
#
#    3. Informe os 7 últimos dígitos do seu RA (109048xxxxxxx)  \
# 0                                            2013044
# 1                                            2013047
# 2                                            2011047
# 3                                            2013029
# 4                                            2013005
#
# ...

# %%
date["2. Em qual período?"].head()
# Out:
# 0     Noturno
# 1     Noturno
# 2    Matutino
# 3     Noturno
# 4     Noturno
# Name: 2. Em qual período?, dtype: object
